# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
#  - 1	id: Unique identifier for each record.
# - 2	customer_id: Unique identifier for each customer.
# - 3	month: Month of the transaction or record.
# - 4	name: Customer’s name.
# - 5	age: The customer’s age.
# - 6	ssn: Customer’s social security number.
# - 7	occupation: The customer’s occupation.
# - 8	annual_income: The customer’s annual income.
# - 9	monthly_inhand_salary: The customer’s monthly take-home salary.
# - 10	num_bank_accounts: Total number of bank accounts owned by the customer.
# - 11	num_credit_card: Total number of credit cards held by the customer.
# - 12	interest_rate: The interest rate applied to loans or credits.
# - 13	num_of_loan: Number of loans the customer has taken.
# - 14	type_of_loan: Categories of loans obtained by the customer.
# - 15	delay_from_due_date: The delay in payment relative to the due date.
# - 16	num_of_delayed_payment: Total instances of late payments made by the customer.
# - 17	changed_credit_limit: Adjustments made to the customer’s credit limit.
# - 18	num_credit_inquiries: Number of inquiries made regarding the customer's credit.
# - 19	credit_mix: The variety of credit types the customer uses (e.g., loans, credit cards).
# - 20	outstanding_debt: Total amount of debt the customer currently owes.
# - 21	credit_utilization_ratio: Proportion of credit used compared to the total credit limit.
# - 22	credit_history_age: Duration of the customer’s credit history.
# - 23	payment_of_min_amount: Indicates if the customer pays the minimum required amount each month.
# - 24	total_emi_per_month: Total Equated Monthly Installment (EMI) paid by the customer.
# - 25	amount_invested_monthly: Monthly investment amount made by the customer.
# - 26	payment_behaviour: Customer’s payment habits and tendencies.
# - 27	monthly_balance: The remaining balance in the customer’s account at the end of each month.
# - 28	credit_score: The customer’s credit score (target variable: "Good," "Poor," "Standard").

# %%
Train_Data=pd.read_csv('credit_score_cleaned_train.csv')
Train_Data
# Out:
#             id customer_id     month           name  age          ssn  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh   23  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265
# ...        ...         ...       ...            ...  ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks   25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks   25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks   25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks   25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks   25  078-73-5990
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# ...

# %%
data=Train_Data.copy()
data
# Out:
#             id customer_id     month           name  age          ssn  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh   23  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265
# ...        ...         ...       ...            ...  ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks   25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks   25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks   25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks   25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks   25  078-73-5990
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# ...

# %% [markdown]
# # Data Description

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        100000 non-null  object
#  1   customer_id               100000 non-null  object
#  2   month                     100000 non-null  object
#  3   name                      100000 non-null  object
#  4   age                       100000 non-null  int64
#  5   ssn                       100000 non-null  object
#  6   occupation                100000 non-null  object
#  7   annual_income             100000 non-null  float64
#  8   monthly_inhand_salary     100000 non-null  float64
#  9   total_emi_per_month       100000 non-null  float64
#  10  num_bank_accounts         100000 non-null  int64
#  11  num_credit_card           100000 non-null  int64
#  12  interest_rate             100000 non-null  int64
# ...

# %%
data['Name']=data['Name'].fillna("Unknown")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Name'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        100000 non-null  object
#  1   customer_id               100000 non-null  object
#  2   month                     100000 non-null  object
#  3   name                      100000 non-null  object
#  4   age                       100000 non-null  int64
#  5   ssn                       100000 non-null  object
#  6   occupation                100000 non-null  object
#  7   annual_income             100000 non-null  float64
#  8   monthly_inhand_salary     100000 non-null  float64
#  9   total_emi_per_month       100000 non-null  float64
#  10  num_bank_accounts         100000 non-null  int64
#  11  num_credit_card           100000 non-null  int64
#  12  interest_rate             100000 non-null  int64
# ...

# %%
data['monthly_inhand_salary']=data['monthly_inhand_salary'].fillna(0)

# %%
data['type_of_loan']=data['type_of_loan'].fillna('unknown')

# %%
data['num_of_delayed_payment']=data['num_of_delayed_payment'].fillna(0)

# %%
data['num_credit_inquiries']=data['num_credit_inquiries'].fillna(0)

# %%
data['credit_history_age']=data['credit_history_age'].fillna('unknown')

# %%
data['amount_invested_monthly']=data['amount_invested_monthly'].fillna(0)

# %%
data['monthly_balance']=data['monthly_balance'].fillna(0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   id                        100000 non-null  object
#  1   customer_id               100000 non-null  object
#  2   month                     100000 non-null  object
#  3   name                      100000 non-null  object
#  4   age                       100000 non-null  int64
#  5   ssn                       100000 non-null  object
#  6   occupation                100000 non-null  object
#  7   annual_income             100000 non-null  float64
#  8   monthly_inhand_salary     100000 non-null  float64
#  9   total_emi_per_month       100000 non-null  float64
#  10  num_bank_accounts         100000 non-null  int64
#  11  num_credit_card           100000 non-null  int64
#  12  interest_rate             100000 non-null  int64
# ...

# %%
data['amount_invested_monthly']
# Out:
# 0         80.415300
# 1        118.280220
# 2         81.699524
# 3        199.458070
# 4         41.420155
#             ...
# 99995     60.971333
# 99996     54.185950
# 99997     24.028477
# 99998    251.672580
# 99999    167.163860
# Name: amount_invested_monthly, Length: 100000, dtype: float64

# %%
data['amount_invested_monthly'].dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 data['amount_invested_monthly'].dtype()
#
# TypeError: 'numpy.dtype[float64]' object is not callable

# %%
data.describe()
# Out:
#                  age  annual_income  monthly_inhand_salary  \
# count  100000.000000  100000.000000          100000.000000
# mean       33.309240   50505.123439            4198.771620
# std        10.764996   38299.422075            3187.494355
# min        14.000000    7005.930000             303.645420
# 25%        24.000000   19342.972500            1626.761700
# 50%        33.000000   36999.705000            3096.378400
# 75%        42.000000   71683.470000            5961.745000
# max        56.000000  179987.280000           15204.634000
#
#        total_emi_per_month  num_bank_accounts  num_credit_card  interest_rate  \
# count        100000.000000      100000.000000    100000.000000   100000.00000
# mean            107.043617           5.368800         5.533640       14.53208
# std             130.035096           2.593279         2.067073        8.74133
# min               0.000000           0.000000         0.000000        1.00000
# ...

# %%
data
# Out:
#             id customer_id     month           name  age          ssn  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh   23  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265
# ...        ...         ...       ...            ...  ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks   25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks   25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks   25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks   25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks   25  078-73-5990
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# ...

# %%
data.columns
# Out:
# Index(['id', 'customer_id', 'month', 'name', 'age', 'ssn', 'occupation',
#        'annual_income', 'monthly_inhand_salary', 'total_emi_per_month',
#        'num_bank_accounts', 'num_credit_card', 'interest_rate', 'num_of_loan',
#        'type_of_loan', 'delay_from_due_date', 'num_of_delayed_payment',
#        'changed_credit_limit', 'num_credit_inquiries', 'credit_mix',
#        'outstanding_debt', 'credit_utilization_ratio', 'credit_history_age',
#        'payment_of_min_amount', 'amount_invested_monthly', 'payment_behaviour',
#        'monthly_balance', 'credit_score'],
#       dtype='object')

# %%
data['month']
# Out:
# 0         January
# 1        February
# 2           March
# 3           April
# 4             May
#            ...
# 99995       April
# 99996         May
# 99997        June
# 99998        July
# 99999      August
# Name: month, Length: 100000, dtype: object

# %% [markdown]
# ### The details of the Month:Augest and there details

# %%
month_AUG=data[data['month']=='August']
month_AUG
# Out:
#             id customer_id   month             name  age          ssn  \
# 7       0x1609   CUS_0xd40  August    Aaron Maashoh   23  821-00-0265
# 15      0x1615  CUS_0x21b1  August  Rick Rothackerj   28  004-07-5839
# 23      0x1621  CUS_0x2dbc  August           Langep   34  486-85-3974
# 31      0x162d  CUS_0xb891  August           Jasond   55  072-31-6145
# 39      0x1639  CUS_0x1cdb  August           Deepaa   21  615-06-7821
# ...        ...         ...     ...              ...  ...          ...
# 99967  0x25fbd  CUS_0x372c  August  Lucia Mutikanik   19  340-85-7301
# 99975  0x25fc9   CUS_0xf16  August   Maria Sheahanb   45  868-70-2218
# 99983  0x25fd5  CUS_0xaf61  August   Chris Wickhamm   50  133-16-7738
# 99991  0x25fe1  CUS_0x8600  August   Sarah McBridec   29  031-35-0942
# 99999  0x25fed  CUS_0x942c  August            Nicks   25  078-73-5990
#
#           occupation  annual_income  monthly_inhand_salary  \
# 7          Scientist       19114.12              1824.8434
# ...

# %% [markdown]
# - TAKEAWAY : There were 12500 customer records in august month

# %% [markdown]
# ### I want to know the details of the occupation lawyer details and want know the count of them

# %%
lawyer=data[data['occupation']=='Lawyer']
lawyer
# Out:
#             id customer_id     month             name  age          ssn  \
# 40      0x163e  CUS_0x95ee   January               Np   31  612-70-8987
# 41      0x163f  CUS_0x95ee  February               Np   31  612-70-8987
# 42      0x1640  CUS_0x95ee     March               Np   31  612-70-8987
# 43      0x1641  CUS_0x95ee     April               Np   31  612-70-8987
# 44      0x1642  CUS_0x95ee       May               Np   31  612-70-8987
# ...        ...         ...       ...              ...  ...          ...
# 99963  0x25fb9  CUS_0x372c     April  Lucia Mutikanik   18  340-85-7301
# 99964  0x25fba  CUS_0x372c       May  Lucia Mutikanik   18  340-85-7301
# 99965  0x25fbb  CUS_0x372c      June  Lucia Mutikanik   19  340-85-7301
# 99966  0x25fbc  CUS_0x372c      July  Lucia Mutikanik   19  340-85-7301
# 99967  0x25fbd  CUS_0x372c    August  Lucia Mutikanik   19  340-85-7301
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# ...

# %% [markdown]
# - TAKEAWAY : There were 6575 Lawyers who were recorded in this bank

# %% [markdown]
# ### Get the details of top 10 customers whose income is higher

# %%
top_10_annualIncome=data.sort_values(by='annual_income',ascending=True).head(10)
top_10_annualIncome
# Out:
#             id customer_id     month          name  age          ssn  \
# 39673   0xfe77  CUS_0x183d  February        Whiteb   14  259-11-0934
# 39679   0xfe7d  CUS_0x183d    August        Whiteb   15  259-11-0934
# 39678   0xfe7c  CUS_0x183d      July        Whiteb   14  259-11-0934
# 39677   0xfe7b  CUS_0x183d      June        Whiteb   14  259-11-0934
# 39676   0xfe7a  CUS_0x183d       May        Whiteb   14  259-11-0934
# 39675   0xfe79  CUS_0x183d     April        Whiteb   14  259-11-0934
# 39672   0xfe76  CUS_0x183d   January        Whiteb   14  259-11-0934
# 39674   0xfe78  CUS_0x183d     March        Whiteb   14  259-11-0934
# 80029  0x1eaeb  CUS_0x7d4b      June  Jason Langej   43  975-45-7784
# 80024  0x1eae6  CUS_0x7d4b   January  Jason Langej   43  975-45-7784
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# 39673     Writer       7005.930              835.82750            18.672909
# ...

# %% [markdown]
# - TAKEAWAY: these are the top 10 annual income customers and Clarer the journalist having around 1cr annual_income

# %% [markdown]
# ### The customers whose having 10 or more bank accounts

# %%
bank_accnt=data[data['num_bank_accounts']>=10]
bank_accnt
# Out:
#             id customer_id     month            name  age          ssn  \
# 232     0x175e  CUS_0xb681   January          Sarahb   37  904-88-7361
# 233     0x175f  CUS_0xb681  February          Sarahb   37  904-88-7361
# 234     0x1760  CUS_0xb681     March          Sarahb   37  904-88-7361
# 235     0x1761  CUS_0xb681     April          Sarahb   37  904-88-7361
# 236     0x1762  CUS_0xb681       May          Sarahb   37  904-88-7361
# ...        ...         ...       ...             ...  ...          ...
# 99987  0x25fdd  CUS_0x8600     April  Sarah McBridec   28  031-35-0942
# 99988  0x25fde  CUS_0x8600       May  Sarah McBridec   28  031-35-0942
# 99989  0x25fdf  CUS_0x8600      June  Sarah McBridec   28  031-35-0942
# 99990  0x25fe0  CUS_0x8600      July  Sarah McBridec   28  031-35-0942
# 99991  0x25fe1  CUS_0x8600    August  Sarah McBridec   29  031-35-0942
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# ...

# %% [markdown]
# - TAKE AWAY: There were 577 customers having 10 and more accounts in the bank

# %% [markdown]
# ### The customer whose occupation is Manager and having more than 10 accounts in the bank

# %%
Manager_10=bank_accnt[(bank_accnt['num_bank_accounts']>=10)&(bank_accnt['occupation']=='Manager')]
Manager_10
# Out:
#             id customer_id     month             name  age          ssn  \
# 232     0x175e  CUS_0xb681   January           Sarahb   37  904-88-7361
# 233     0x175f  CUS_0xb681  February           Sarahb   37  904-88-7361
# 234     0x1760  CUS_0xb681     March           Sarahb   37  904-88-7361
# 235     0x1761  CUS_0xb681     April           Sarahb   37  904-88-7361
# 236     0x1762  CUS_0xb681       May           Sarahb   37  904-88-7361
# ...        ...         ...       ...              ...  ...          ...
# 98827  0x25911  CUS_0x5cc4     April  Jennifer Ablanl   39  868-70-5450
# 98828  0x25912  CUS_0x5cc4       May  Jennifer Ablanl   39  868-70-5450
# 98829  0x25913  CUS_0x5cc4      June  Jennifer Ablanl   40  868-70-5450
# 98830  0x25914  CUS_0x5cc4      July  Jennifer Ablanl   40  868-70-5450
# 98831  0x25915  CUS_0x5cc4    August  Jennifer Ablanl   40  868-70-5450
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# ...

# %% [markdown]
# - TAKEAWAY : There were 11 Manager customers whose having number of bank account more than 1500

# %%
data['total_emi_per_month'].sort_values(ascending=False).head()
# Out:
# 15879    3776.0000
# 60288    2523.0000
# 46024    1867.0000
# 35478    1779.1033
# 35477    1779.1033
# Name: total_emi_per_month, dtype: float64

# %% [markdown]
# ### The customers who is yet to pay EMI having more than 1000

# %%
EMI_50000=data[data['total_emi_per_month']>=1000]
EMI_50000
# Out:
#             id customer_id   month               name  age          ssn  \
# 565     0x194f  CUS_0x2827    June              Lisah   18  486-07-1289
# 566     0x1950  CUS_0x2827    July              Lisah   18  486-07-1289
# 567     0x1951  CUS_0x2827  August              Lisah   18  486-07-1289
# 811     0x1ac1  CUS_0x6435   April  Alexei Oreskovicf   27  538-49-2118
# 812     0x1ac2  CUS_0x6435     May  Alexei Oreskovicf   27  538-49-2118
# ...        ...         ...     ...                ...  ...          ...
# 94861  0x241d3  CUS_0x5e18    June           Kuehnenn   49  287-80-7372
# 94862  0x241d4  CUS_0x5e18    July           Kuehnenn   49  287-80-7372
# 94863  0x241d5  CUS_0x5e18  August           Kuehnenn   50  287-80-7372
# 99239  0x25b79  CUS_0x56e5  August              Gregq   24  823-62-0090
# 99519  0x25d1d  CUS_0x10f9  August  Gilles Guillaumev   54  746-79-6875
#
#           occupation  annual_income  monthly_inhand_salary  \
# ...

# %% [markdown]
# - TAKEAWAY : There were 1227 customers who having Total_EMI more than 1000

# %%
data['credit_score'].unique()
# Out:
# array([2, 1, 0], dtype=int64)

# %% [markdown]
# ### Customers who having credit score good (Here: 2-good,1-normal,0-bad)

# %%
Good_score=data[(data['credit_score']==2)]
Good_score
# Out:
#             id customer_id     month            name  age          ssn  \
# 0       0x1602   CUS_0xd40   January   Aaron Maashoh   23  821-00-0265
# 1       0x1603   CUS_0xd40  February   Aaron Maashoh   23  821-00-0265
# 2       0x1604   CUS_0xd40     March   Aaron Maashoh   23  821-00-0265
# 3       0x1605   CUS_0xd40     April   Aaron Maashoh   23  821-00-0265
# 4       0x1606   CUS_0xd40       May   Aaron Maashoh   23  821-00-0265
# ...        ...         ...       ...             ...  ...          ...
# 99978  0x25fd0  CUS_0xaf61     March  Chris Wickhamm   49  133-16-7738
# 99979  0x25fd1  CUS_0xaf61     April  Chris Wickhamm   49  133-16-7738
# 99981  0x25fd3  CUS_0xaf61      June  Chris Wickhamm   50  133-16-7738
# 99982  0x25fd4  CUS_0xaf61      July  Chris Wickhamm   50  133-16-7738
# 99983  0x25fd5  CUS_0xaf61    August  Chris Wickhamm   50  133-16-7738
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# ...

# %% [markdown]
# - TAKEAWAY : There were 17828 customers having a good credit score

# %% [markdown]
# ### Which occupation having most credit score

# %%
A=Good_score['occupation'].value_counts()

# %%
occu=pd.DataFrame(A).reset_index()
occu
# Out:
#        occupation  count
# 0        Engineer   1264
# 1          Lawyer   1259
# 2      Journalist   1254
# 3   Media_Manager   1244
# 4       Architect   1233
# 5         Teacher   1224
# 6       Developer   1210
# 7      Accountant   1205
# 8       Scientist   1201
# 9        Musician   1192
# 10        Manager   1190
# 11   Entrepreneur   1185
# 12         Doctor   1164
# 13       Mechanic   1107
# 14         Writer    896

# %%
plt.title('occupation having most credit score')
plt.bar(occu['occupation'],occu['count'])
plt.xlabel('Occupation')
plt.ylabel('No: of good credit_score')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ### All month number of bank accounts

# %%
data
# Out:
#             id customer_id     month           name  age          ssn  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh   23  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265
# ...        ...         ...       ...            ...  ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks   25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks   25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks   25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks   25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks   25  078-73-5990
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# ...

# %%
data['month'].nunique()
# Out:
# 8

# %%
month_group=data.groupby('month')['num_bank_accounts'].sum()
month_group=pd.DataFrame(month_group).reset_index()
month_group
# Out:
#       month  num_bank_accounts
# 0     April              67122
# 1    August              67110
# 2  February              67105
# 3   January              67093
# 4      July              67107
# 5      June              67114
# 6     March              67115
# 7       May              67114

# %%
plt.title('Number of bank accounts in month by percentage')
plt.pie(month_group['num_bank_accounts'],labels=month_group['month'],autopct='%1.2f%%',shadow=True);

# %% [markdown]
# - TAKEAWAY: In all the months there were a common number of accounts where opened

# %%
data
# Out:
#             id customer_id     month           name  age          ssn  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh   23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh   23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh   23  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh   23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh   23  821-00-0265
# ...        ...         ...       ...            ...  ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks   25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks   25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks   25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks   25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks   25  078-73-5990
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# ...

# %%
data['payment_behaviour'].unique()
# Out:
# array(['High_spent_Small_value_payments',
#        'Low_spent_Large_value_payments',
#        'Low_spent_Medium_value_payments',
#        'Low_spent_Small_value_payments',
#        'High_spent_Medium_value_payments',
#        'High_spent_Large_value_payments'], dtype=object)

# %% [markdown]
# ### Top 10 annual income customers.I want to know there payment behaviour

# %%
Top_10_annual_income=data.sort_values(by='annual_income',ascending=False).head(10)
Top_10_annual_income.loc[:,['name','annual_income','payment_behaviour']]
# Out:
#                   name  annual_income                 payment_behaviour
# 15688  Olga Dzyubenkop      179987.28    Low_spent_Small_value_payments
# 15695  Olga Dzyubenkop      179987.28   High_spent_Large_value_payments
# 15689  Olga Dzyubenkop      179987.28   High_spent_Large_value_payments
# 15690  Olga Dzyubenkop      179987.28   Low_spent_Medium_value_payments
# 15691  Olga Dzyubenkop      179987.28   High_spent_Large_value_payments
# 15692  Olga Dzyubenkop      179987.28  High_spent_Medium_value_payments
# 15693  Olga Dzyubenkop      179987.28   High_spent_Large_value_payments
# 15694  Olga Dzyubenkop      179987.28  High_spent_Medium_value_payments
# 8693          Woodallf      179948.84   Low_spent_Medium_value_payments
# 8692          Woodallf      179948.84   Low_spent_Medium_value_payments

# %%
data['age'].unique()
# Out:
# array([23, 28, 34, 54, 55, 21, 31, 33, 30, 24, 44, 45, 40, 41, 32, 35, 36,
#        39, 37, 20, 46, 26, 42, 19, 48, 38, 43, 22, 16, 18, 15, 27, 25, 14,
#        17, 47, 53, 56, 29, 49, 51, 50, 52], dtype=int64)

# %% [markdown]
# ### The details of the customers based on the age 20-35 whose occupation is Manager,Take top 5

# %%
df=data[(data['age']>20)&(data['age']<35)&(data['occupation']=='Manager')]
df=df.sort_values(by='annual_income',ascending=False)
df=df.head(10)
df
# Out:
#             id customer_id     month           name  age          ssn  \
# 69478  0x1ad18  CUS_0x4712      July  Karen Jacobsa   25  041-78-8194
# 69475  0x1ad15  CUS_0x4712     April  Karen Jacobsa   25  041-78-8194
# 69473  0x1ad13  CUS_0x4712  February  Karen Jacobsa   25  041-78-8194
# 69474  0x1ad14  CUS_0x4712     March  Karen Jacobsa   25  041-78-8194
# 69479  0x1ad19  CUS_0x4712    August  Karen Jacobsa   25  041-78-8194
# 69472  0x1ad12  CUS_0x4712   January  Karen Jacobsa   24  041-78-8194
# 69477  0x1ad17  CUS_0x4712      June  Karen Jacobsa   25  041-78-8194
# 69476  0x1ad16  CUS_0x4712       May  Karen Jacobsa   25  041-78-8194
# 88085  0x21a1f  CUS_0x489b      June        Malonem   31  769-46-3750
# 88086  0x21a20  CUS_0x489b      July        Malonem   31  769-46-3750
#
#       occupation  annual_income  monthly_inhand_salary  total_emi_per_month  \
# 69478    Manager      178283.69              14835.974            328.23843
# ...

# %% [markdown]
# ### The customer name Karen Jacobsa deatils

# %%
Jacobs_details=data[data['name']=='Karen Jacobsa']
Jacobs_details
# Out:
#             id customer_id     month           name  age          ssn  \
# 36440   0xeb86  CUS_0x51bf   January  Karen Jacobsa   50  684-71-5126
# 36441   0xeb87  CUS_0x51bf  February  Karen Jacobsa   51  684-71-5126
# 36442   0xeb88  CUS_0x51bf     March  Karen Jacobsa   51  684-71-5126
# 36443   0xeb89  CUS_0x51bf     April  Karen Jacobsa   51  684-71-5126
# 36444   0xeb8a  CUS_0x51bf       May  Karen Jacobsa   51  684-71-5126
# 36445   0xeb8b  CUS_0x51bf      June  Karen Jacobsa   51  684-71-5126
# 36446   0xeb8c  CUS_0x51bf      July  Karen Jacobsa   51  684-71-5126
# 36447   0xeb8d  CUS_0x51bf    August  Karen Jacobsa   51  684-71-5126
# 69472  0x1ad12  CUS_0x4712   January  Karen Jacobsa   24  041-78-8194
# 69473  0x1ad13  CUS_0x4712  February  Karen Jacobsa   25  041-78-8194
# 69474  0x1ad14  CUS_0x4712     March  Karen Jacobsa   25  041-78-8194
# 69475  0x1ad15  CUS_0x4712     April  Karen Jacobsa   25  041-78-8194
# ...

# %% [markdown]
# ### The details of the customer name Malonem

# %%
Malonem_detials=data[data['name']=='Malonem']
Malonem_detials
# Out:
#             id customer_id     month     name  age          ssn    occupation  \
# 38376   0xf6de  CUS_0x4d0f   January  Malonem   29  542-51-9266  Entrepreneur
# 38377   0xf6df  CUS_0x4d0f  February  Malonem   29  542-51-9266  Entrepreneur
# 38378   0xf6e0  CUS_0x4d0f     March  Malonem   29  542-51-9266  Entrepreneur
# 38379   0xf6e1  CUS_0x4d0f     April  Malonem   29  542-51-9266  Entrepreneur
# 38380   0xf6e2  CUS_0x4d0f       May  Malonem   29  542-51-9266  Entrepreneur
# 38381   0xf6e3  CUS_0x4d0f      June  Malonem   29  542-51-9266  Entrepreneur
# 38382   0xf6e4  CUS_0x4d0f      July  Malonem   30  542-51-9266  Entrepreneur
# 38383   0xf6e5  CUS_0x4d0f    August  Malonem   30  542-51-9266  Entrepreneur
# 88080  0x21a1a  CUS_0x489b   January  Malonem   31  769-46-3750       Manager
# 88081  0x21a1b  CUS_0x489b  February  Malonem   31  769-46-3750       Manager
# 88082  0x21a1c  CUS_0x489b     March  Malonem   31  769-46-3750       Manager
# ...
